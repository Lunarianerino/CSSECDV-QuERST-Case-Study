# %% [markdown]
# # SVT 2025 Matching

# %%
import json
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
with open('transformed_data.json', 'r') as f:
    data = json.load(f)

tutors = [d for d in data if d['Type'] == 'tutor']
students = [d for d in data if d['Type'] == 'student']

# %% [markdown]
# ## BFI and VARK feature extraction

# %%
def feature_vector(entity):
    vark = entity['VARK Results']
    bfi = entity['BFI Results']
    return np.array([
        vark['V'], vark['A'], vark['R'], vark['K'],
        bfi['Openness'], bfi['Conscientiousness'], bfi['Extroversion'],
        bfi['Agreeableness'], bfi['Neuroticism']
    ], dtype=float)

# %%
tutor_features = {t['Name']: feature_vector(t) for t in tutors}
student_features = {s['Name']: feature_vector(s) for s in students}

# %% [markdown]
# ## Getting Tutor Pairing Limits

# %%
capacity = {t['Name']: t['Pair Limit'] for t in tutors}

# %% [markdown]
# ## Getting Student Quartile

# %%
def quartile_num(q):
    return int(str(q)[0])

# %%
# Sort students by lowest quartile first
sorted_students = sorted(students, key=lambda s: s['Quartile'])

# %%
sorted_students
# Out:
# [{'Name': 'Alab, Precious Pearl',
#   'Type': 'student',
#   'VARK Results': {'V': 4, 'A': 2, 'R': 5, 'K': 7},
#   'BFI Results': {'Openness': 3.75,
#    'Conscientiousness': 3.25,
#    'Extroversion': 3.75,
#    'Agreeableness': 5.0,
#    'Neuroticism': 4.0},
#   'Quartile': '2b',
#   'Schedule': {'Monday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Tuesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Wednesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Thursday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Friday': {'intervals': [{'start': '08:00', 'end': '21:00'}]}}},
#  {'Name': 'Alviar, Loissah Mharie',
#   'Type': 'student',
#   'VARK Results': {'V': 6, 'A': 4, 'R': 5, 'K': 1},
#   'BFI Results': {'Openness': 3.5,
#    'Conscientiousness': 3.25,
#    'Extroversion': 4.0,
#    'Agreeableness': 3.0,
#    'Neuroticism': 4.5},
#   'Quartile': '2b',
#   'Schedule': {'Monday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Tuesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Wednesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Thursday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Friday': {'intervals': [{'start': '08:00', 'end': '21:00'}]}}},
#  {'Name': 'Capillano, Mhigz Genrei',
#   'Type': 'student',
#   'VARK Results': {'V': 6, 'A': 5, 'R': 10, 'K': 7},
#   'BFI Results': {'Openness': 4.0,
#    'Conscientiousness': 4.75,
#    'Extroversion': 4.0,
#    'Agreeableness': 4.5,
#    'Neuroticism': 2.5},
#   'Quartile': '2b',
#   'Schedule': {'Monday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Tuesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Wednesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Thursday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Friday': {'intervals': [{'start': '08:00', 'end': '21:00'}]}}},
#  {'Name': 'Orain, Mark Angelo',
#   'Type': 'student',
#   'VARK Results': {'V': 5, 'A': 3, 'R': 4, 'K': 4},
#   'BFI Results': {'Openness': 2.5,
#    'Conscientiousness': 2.5,
#    'Extroversion': 3.5,
#    'Agreeableness': 4.0,
#    'Neuroticism': 1.75},
#   'Quartile': '2b',
#   'Schedule': {'Monday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Tuesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Wednesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Thursday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Friday': {'intervals': [{'start': '08:00', 'end': '21:00'}]}}},
#  {'Name': 'Baloaloa, Akhira Charlotte',
#   'Type': 'student',
#   'VARK Results': {'V': 3, 'A': 5, 'R': 0, 'K': 8},
#   'BFI Results': {'Openness': 4.25,
#    'Conscientiousness': 3.75,
#    'Extroversion': 4.25,
#    'Agreeableness': 4.5,
#    'Neuroticism': 3.25},
#   'Quartile': '3a',
#   'Schedule': {'Monday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Tuesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Wednesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Thursday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Friday': {'intervals': [{'start': '08:00', 'end': '21:00'}]}}},
#  {'Name': 'Llanto, Didrei Keira',
#   'Type': 'student',
#   'VARK Results': {'V': 9, 'A': 0, 'R': 6, 'K': 1},
#   'BFI Results': {'Openness': 4.75,
#    'Conscientiousness': 4.0,
#    'Extroversion': 4.75,
#    'Agreeableness': 4.0,
#    'Neuroticism': 4.25},
#   'Quartile': '3a',
#   'Schedule': {'Monday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Tuesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Wednesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Thursday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Friday': {'intervals': [{'start': '08:00', 'end': '21:00'}]}}},
#  {'Name': 'Panaguiton, Lei Janrey',
#   'Type': 'student',
#   'VARK Results': {'V': 6, 'A': 5, 'R': 9, 'K': 8},
#   'BFI Results': {'Openness': 3.0,
#    'Conscientiousness': 2.75,
#    'Extroversion': 3.0,
#    'Agreeableness': 3.25,
#    'Neuroticism': 2.75},
#   'Quartile': '3a',
#   'Schedule': {'Monday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Tuesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Wednesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Thursday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Friday': {'intervals': [{'start': '08:00', 'end': '21:00'}]}}},
#  {'Name': 'Panopio, Kyrie Caleb',
#   'Type': 'student',
#   'VARK Results': {'V': 2, 'A': 9, 'R': 3, 'K': 8},
#   'BFI Results': {'Openness': 3.5,
#    'Conscientiousness': 3.25,
#    'Extroversion': 3.75,
#    'Agreeableness': 2.75,
#    'Neuroticism': 4.25},
#   'Quartile': '3a',
#   'Schedule': {'Monday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Tuesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Wednesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Thursday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Friday': {'intervals': [{'start': '08:00', 'end': '21:00'}]}}},
#  {'Name': 'Poblete, Erica',
#   'Type': 'student',
#   'VARK Results': {'V': 3, 'A': 5, 'R': 4, 'K': 4},
#   'BFI Results': {'Openness': 3.25,
#    'Conscientiousness': 4.0,
#    'Extroversion': 3.5,
#    'Agreeableness': 4.25,
#    'Neuroticism': 4.25},
#   'Quartile': '3a',
#   'Schedule': {'Monday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Tuesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Wednesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Thursday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Friday': {'intervals': [{'start': '08:00', 'end': '21:00'}]}}},
#  {'Name': 'Alcoran, Mark Jhei',
#   'Type': 'student',
#   'VARK Results': {'V': 0, 'A': 5, 'R': 5, 'K': 7},
#   'BFI Results': {'Openness': 4.5,
#    'Conscientiousness': 4.0,
#    'Extroversion': 4.75,
#    'Agreeableness': 5.0,
#    'Neuroticism': 4.25},
#   'Quartile': '3b',
#   'Schedule': {'Monday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Tuesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Wednesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Thursday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Friday': {'intervals': [{'start': '08:00', 'end': '21:00'}]}}},
#  {'Name': 'Moslares, Khim Steffi',
#   'Type': 'student',
#   'VARK Results': {'V': 5, 'A': 2, 'R': 3, 'K': 6},
#   'BFI Results': {'Openness': 3.25,
#    'Conscientiousness': 3.25,
#    'Extroversion': 4.0,
#    'Agreeableness': 4.25,
#    'Neuroticism': 4.5},
#   'Quartile': '3b',
#   'Schedule': {'Monday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Tuesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Wednesday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Thursday': {'intervals': [{'start': '08:00', 'end': '21:00'}]},
#    'Friday': {'intervals': [{'start': '08:00', 'end': '21:00'}]}}}]

# %% [markdown]
# ## Assign student to tutors

# %%
def matching_function():
    assignments = []
    for s in sorted_students:
        name = s['Name']
        q = quartile_num(s['Quartile'])
        vec = student_features[name].reshape(1, -1)

        # Select candidates based on rules
        candidates = [t for t in tutors if capacity[t['Name']] > 0]

        # if q == 2:
        #     # Only tutors with Pair Limit == 1
        #     candidates = [t for t in tutors if capacity[t['Name']] == 1]
        # else:
        #     # Any tutor with available capacity
        #     candidates = [t for t in tutors if capacity[t['Name']] > 0]

        # If no tutor candidates
        if not candidates:
            assignments.append({'Student': name, 'Tutor': None, 'Similarity': None})
            continue

        # Compute similarities
        sims = [
            (t['Name'], cosine_similarity(vec, tutor_features[t['Name']].reshape(1, -1))[0][0])
            for t in candidates
        ]

        # Sort sims by cosine similarity
        sorted_sims = sorted(sims, key=lambda x: x[1], reverse=True)
        print(f"Name: {name}, Q: {q}, Similarity: {sorted_sims}")
        best_tutor, sim_score = max(sims, key=lambda x: x[1])

        assignments.append({
            'Student': name,
            'Tutor': best_tutor,
            'Similarity': round(sim_score, 3)
        })

        # capacity[best_tutor] -= 1

    results = pd.DataFrame(assignments)
    return results

# %%
matching_function()
# Out:
# Name: Alab, Precious Pearl, Q: 2, Similarity: [('Leon Antonio C. Besar', np.float64(0.9128881946063088)), ('Luis Miguel Antonio Razon', np.float64(0.9116963311125649)), ('Axl Roel Andaya', np.float64(0.9109163921242867)), ('Bianca Clarizze Sollesta', np.float64(0.8740914165301013)), ('Kevin Matthew Panuelos', np.float64(0.8568895764866192)), ('Raymund Sison', np.float64(0.8345727849868285)), ('Bea Claire Sollesta', np.float64(0.8250932080946093)), ('BORJA, Jacob M', np.float64(0.8070533372957108))]
# Name: Alviar, Loissah Mharie, Q: 2, Similarity: [('Raymund Sison', np.float64(0.8848741291144082)), ('Bea Claire Sollesta', np.float64(0.8700959938343993)), ('Bianca Clarizze Sollesta', np.float64(0.8335075418559169)), ('Axl Roel Andaya', np.float64(0.8046525757142029)), ('Kevin Matthew Panuelos', np.float64(0.7171806099508198)), ('Leon Antonio C. Besar', np.float64(0.6982224124339607)), ('BORJA, Jacob M', np.float64(0.685250781044602)), ('Luis Miguel Antonio Razon', np.float64(0.6448889407473684))]
# Name: Capillano, Mhigz Genrei, Q: 2, Similarity: [('Bianca Clarizze Sollesta', np.float64(0.9545964788057982)), ('Raymund Sison', np.float64(0.9469578988170089)), ('Bea Claire Sollesta', np.float64(0.9429900428286229)), ('Axl Roel Andaya', np.float64(0.9006639755168986)), ('Luis Miguel Antonio Razon', np.float64(0.8696316611865978)), ('Leon Antonio C. Besar', np.float64(0.8639120302247228)), ('Kevin Matthew Panuelos', np.float64(0.8255361949638829)), ('BORJA, Jacob M', np.float64(0.7614472852884346))]
# Name: Orain, Mark Angelo, Q: 2, Similarity: [('Axl Roel Andaya', np.float64(0.9194749342591958)), ('Bianca Clarizze Sollesta', np.float64(0.9152833166300761)), ('Raymund Sison', np.float64(0.9045118202383021)), ('Bea Claire Sollesta', np.float64(0.8935004449906736)), ('Leon Antonio C. Besar', np.float64(0.8778572166257423)), ('Kevin Matthew Panuelos', np.float64(0.8644754816450502)), ('BORJA, Jacob M', np.float64(0.8321167935381929)), ('Luis Miguel Antonio Razon', np.float64(0.8213217151269623))]
# Name: Baloaloa, Akhira Charlotte, Q: 3, Similarity: [('Axl Roel Andaya', np.float64(0.9357288620029973)), ('BORJA, Jacob M', np.float64(0.9161673381513452)), ('Leon Antonio C. Besar', np.float64(0.912014173673729)), ('Kevin Matthew Panuelos', np.float64(0.8895596551065686)), ('Luis Miguel Antonio Razon', np.float64(0.8613054927001992)), ('Bianca Clarizze Sollesta', np.float64(0.7731433135075988)), ('Bea Claire Sollesta', np.float64(0.7297959602284515)), ('Raymund Sison', np.float64(0.6104725917891997))]
# Name: Llanto, Didrei Keira, Q: 3, Similarity: [('Raymund Sison', np.float64(0.8771728391472594)), ('Bianca Clarizze Sollesta', np.float64(0.7224875936696558)), ('Bea Claire Sollesta', np.float64(0.7207190255564786)), ('Axl Roel Andaya', np.float64(0.6767525715539268)), ('Leon Antonio C. Besar', np.float64(0.6447306179849687)), ('Kevin Matthew Panuelos', np.float64(0.6425465672329339)), ('BORJA, Jacob M', np.float64(0.5752052238176913)), ('Luis Miguel Antonio Razon', np.float64(0.5506355466898344))]
# Name: Panaguiton, Lei Janrey, Q: 3, Similarity: [('Bianca Clarizze Sollesta', np.float64(0.9839981017876238)), ('Bea Claire Sollesta', np.float64(0.9505792975072063)), ('Raymund Sison', np.float64(0.9403080489255452)), ('Axl Roel Andaya', np.float64(0.9247970850227769)), ('Luis Miguel Antonio Razon', np.float64(0.9073663886939227)), ('Leon Antonio C. Besar', np.float64(0.9028439122775764)), ('Kevin Matthew Panuelos', np.float64(0.8763083438589027)), ('BORJA, Jacob M', np.float64(0.8097324628704113))]
# Name: Panopio, Kyrie Caleb, Q: 3, Similarity: [('Axl Roel Andaya', np.float64(0.9572547030254213)), ('BORJA, Jacob M', np.float64(0.8893978002849245)), ('Luis Miguel Antonio Razon', np.float64(0.8866633135269387)), ('Leon Antonio C. Besar', np.float64(0.8740788754367702)), ('Bianca Clarizze Sollesta', np.float64(0.8705271498248094)), ('Kevin Matthew Panuelos', np.float64(0.8688243097898607)), ('Bea Claire Sollesta', np.float64(0.8676115804100774)), ('Raymund Sison', np.float64(0.6690872111782598))]
# Name: Poblete, Erica, Q: 3, Similarity: [('Axl Roel Andaya', np.float64(0.9230367788967694)), ('Bea Claire Sollesta', np.float64(0.8893625015141995)), ('Bianca Clarizze Sollesta', np.float64(0.873332259553983)), ('Luis Miguel Antonio Razon', np.float64(0.8357406162076153)), ('Leon Antonio C. Besar', np.float64(0.8330351982715007)), ('Kevin Matthew Panuelos', np.float64(0.8126435758902188)), ('Raymund Sison', np.float64(0.8057428125130313)), ('BORJA, Jacob M', np.float64(0.8021769139317863))]
# Name: Alcoran, Mark Jhei, Q: 3, Similarity: [('Luis Miguel Antonio Razon', np.float64(0.9053508302864075)), ('Axl Roel Andaya', np.float64(0.8872542649146136)), ('Leon Antonio C. Besar', np.float64(0.8344419663416274)), ('Bianca Clarizze Sollesta', np.float64(0.8174069512529503)), ('Bea Claire Sollesta', np.float64(0.8160192801155798)), ('Kevin Matthew Panuelos', np.float64(0.7607137716396982)), ('BORJA, Jacob M', np.float64(0.7481859027586962)), ('Raymund Sison', np.float64(0.6944851948945433))]
# Name: Moslares, Khim Steffi, Q: 3, Similarity: [('Axl Roel Andaya', np.float64(0.9134698330907786)), ('Leon Antonio C. Besar', np.float64(0.9052211584996567)), ('Kevin Matthew Panuelos', np.float64(0.8791668864400023)), ('Luis Miguel Antonio Razon', np.float64(0.8557676283091024)), ('BORJA, Jacob M', np.float64(0.8464174356763834)), ('Bianca Clarizze Sollesta', np.float64(0.8436700678330724)), ('Raymund Sison', np.float64(0.806743280251683)), ('Bea Claire Sollesta', np.float64(0.791553069619364))]
#                        Student                      Tutor  Similarity
# 0         Alab, Precious Pearl      Leon Antonio C. Besar       0.913
# 1       Alviar, Loissah Mharie              Raymund Sison       0.885
# 2      Capillano, Mhigz Genrei   Bianca Clarizze Sollesta       0.955
# 3           Orain, Mark Angelo            Axl Roel Andaya       0.919
# 4   Baloaloa, Akhira Charlotte            Axl Roel Andaya       0.936
# 5         Llanto, Didrei Keira              Raymund Sison       0.877
# 6       Panaguiton, Lei Janrey   Bianca Clarizze Sollesta       0.984
# 7         Panopio, Kyrie Caleb            Axl Roel Andaya       0.957
# 8               Poblete, Erica            Axl Roel Andaya       0.923
# 9           Alcoran, Mark Jhei  Luis Miguel Antonio Razon       0.905
# 10       Moslares, Khim Steffi            Axl Roel Andaya       0.913

# %% [markdown]
# ## Normalizing and adding weights to BFI and VARK Features

# %%
def normalize(vec):
    norm = np.linalg.norm(vec)
    return vec / norm if norm > 0 else vec

# %%
def feature_vector(entity, weight_vark=0.5, weight_bfi=0.5):
    vark = entity['VARK Results']
    bfi = entity['BFI Results']
    vark_vals = np.array([vark['V'], vark['A'], vark['R'], vark['K']], dtype=float)
    bfi_vals = np.array([
        bfi['Openness'], bfi['Conscientiousness'], bfi['Extroversion'],
        bfi['Agreeableness'], bfi['Neuroticism']
    ], dtype=float)

    # Normalize np arrays
    vark_norm = normalize(vark_vals)
    bfi_norm = normalize(bfi_vals)
    print(f"VARK: {vark_norm}, BFI: {bfi_norm}")
    return np.concatenate([weight_vark * vark_norm, weight_bfi * bfi_norm])

# %%
capacity = {t['Name']: t['Pair Limit'] for t in tutors}
tutor_features = {t['Name']: feature_vector(t) for t in tutors}
student_features = {s['Name']: feature_vector(s) for s in students}
# Out:
# VARK: [0.6094494  0.23440362 0.70321085 0.28128434], BFI: [0.52645984 0.52645984 0.35097323 0.4679643  0.32172546]
# VARK: [0.12082442 0.30206105 0.42288547 0.84577093], BFI: [0.41654687 0.3845048  0.2883786  0.5767572  0.51267307]
# VARK: [0.50251891 0.50251891 0.         0.70352647], BFI: [0.4135851  0.47721357 0.4135851  0.50902781 0.4135851 ]
# VARK: [0.53738517 0.39082557 0.14655959 0.73279795], BFI: [0.45326674 0.51801913 0.29138576 0.45326674 0.48564293]
# VARK: [0.41391868 0.2956562  0.23652496 0.82783735], BFI: [0.5087704  0.5087704  0.3179815  0.5087704  0.34977965]
# VARK: [0.44292808 0.47983876 0.5536601  0.51674943], BFI: [0.45581158 0.37537424 0.42899914 0.50943647 0.45581158]
# VARK: [0.38837867 0.60414459 0.60414459 0.34522548], BFI: [0.54153036 0.40614777 0.40614777 0.46030081 0.40614777]
# VARK: [0.40824829 0.54433105 0.27216553 0.68041382], BFI: [0.40195507 0.49471393 0.40195507 0.49471393 0.43287469]
# VARK: [0.4125685  0.20628425 0.51571062 0.72199487], BFI: [0.42008403 0.36407282 0.42008403 0.56011203 0.44808963]
# VARK: [0.         0.50251891 0.50251891 0.70352647], BFI: [0.44583966 0.39630192 0.47060853 0.4953774  0.42107079]
# VARK: [0.67936622 0.45291081 0.56613852 0.1132277 ], BFI: [0.42424242 0.39393939 0.48484848 0.36363636 0.54545455]
# VARK: [0.30304576 0.50507627 0.         0.80812204], BFI: [0.47222222 0.41666667 0.47222222 0.5        0.36111111]
# VARK: [0.41403934 0.34503278 0.69006556 0.48304589], BFI: [0.44427308 0.52757428 0.44427308 0.49980721 0.27767067]
# VARK: [0.82851716 0.         0.55234477 0.09205746], BFI: [0.4868595  0.40998695 0.4868595  0.40998695 0.43561113]
# VARK: [0.58123819 0.23249528 0.34874292 0.69748583], BFI: [0.37418788 0.37418788 0.46053893 0.48932261 0.5181063 ]
# VARK: [0.61545745 0.36927447 0.49236596 0.49236596], BFI: [0.37769479 0.37769479 0.5287727  0.60431166 0.26438635]
# VARK: [0.41803981 0.34836651 0.62705971 0.55738641], BFI: [0.45388168 0.41605821 0.45388168 0.49170516 0.41605821]
# VARK: [0.15911146 0.71600156 0.23866719 0.63644583], BFI: [0.44271887 0.4110961  0.47434165 0.34785054 0.5375872 ]
# VARK: [0.36927447 0.61545745 0.49236596 0.49236596], BFI: [0.37543414 0.46207279 0.40431369 0.49095233 0.49095233]

# %%
matching_function()
# Out:
# Name: Alab, Precious Pearl, Q: 2, Similarity: [('Bianca Clarizze Sollesta', np.float64(0.9691422680279167)), ('Luis Miguel Antonio Razon', np.float64(0.964887698957011)), ('Leon Antonio C. Besar', np.float64(0.9628337906491484)), ('Axl Roel Andaya', np.float64(0.9506074179946851)), ('Kevin Matthew Panuelos', np.float64(0.9399465345473967)), ('Raymund Sison', np.float64(0.9160360838419489)), ('Bea Claire Sollesta', np.float64(0.9157277812431209)), ('BORJA, Jacob M', np.float64(0.90529249008087))]
# Name: Alviar, Loissah Mharie, Q: 2, Similarity: [('Raymund Sison', np.float64(0.9483656772704956)), ('Bea Claire Sollesta', np.float64(0.9470843644324689)), ('Bianca Clarizze Sollesta', np.float64(0.9366581098101437)), ('Axl Roel Andaya', np.float64(0.8656595240690159)), ('Kevin Matthew Panuelos', np.float64(0.8376989958575134)), ('BORJA, Jacob M', np.float64(0.8116609368195709)), ('Leon Antonio C. Besar', np.float64(0.7944920634170677)), ('Luis Miguel Antonio Razon', np.float64(0.7557226553405699))]
# Name: Capillano, Mhigz Genrei, Q: 2, Similarity: [('Bianca Clarizze Sollesta', np.float64(0.976473056275604)), ('Raymund Sison', np.float64(0.9725700022036848)), ('Bea Claire Sollesta', np.float64(0.9655254212006297)), ('Axl Roel Andaya', np.float64(0.9294691170431709)), ('Leon Antonio C. Besar', np.float64(0.9118096532129703)), ('Luis Miguel Antonio Razon', np.float64(0.9006339134089327)), ('Kevin Matthew Panuelos', np.float64(0.8889872002638171)), ('BORJA, Jacob M', np.float64(0.854897467003234))]
# Name: Orain, Mark Angelo, Q: 2, Similarity: [('Bianca Clarizze Sollesta', np.float64(0.9729875817829601)), ('Raymund Sison', np.float64(0.9487524068067031)), ('Bea Claire Sollesta', np.float64(0.9439006250607368)), ('Axl Roel Andaya', np.float64(0.9429511480546552)), ('Leon Antonio C. Besar', np.float64(0.920188021353968)), ('Kevin Matthew Panuelos', np.float64(0.9156317586497146)), ('BORJA, Jacob M', np.float64(0.9066695595698279)), ('Luis Miguel Antonio Razon', np.float64(0.8748367944924381))]
# Name: Baloaloa, Akhira Charlotte, Q: 3, Similarity: [('BORJA, Jacob M', np.float64(0.9839715297546312)), ('Axl Roel Andaya', np.float64(0.9689659381168205)), ('Leon Antonio C. Besar', np.float64(0.963425822594738)), ('Kevin Matthew Panuelos', np.float64(0.9609631903447582)), ('Luis Miguel Antonio Razon', np.float64(0.9196338352231467)), ('Bianca Clarizze Sollesta', np.float64(0.893864666172211)), ('Bea Claire Sollesta', np.float64(0.8476888574111159)), ('Raymund Sison', np.float64(0.7571286439549846))]
# Name: Llanto, Didrei Keira, Q: 3, Similarity: [('Raymund Sison', np.float64(0.9471415895255798)), ('Bianca Clarizze Sollesta', np.float64(0.8562256841003244)), ('Bea Claire Sollesta', np.float64(0.8403981384332536)), ('Kevin Matthew Panuelos', np.float64(0.7829754535491098)), ('Axl Roel Andaya', np.float64(0.7684079594744753)), ('Leon Antonio C. Besar', np.float64(0.7609245147087693)), ('BORJA, Jacob M', np.float64(0.7341672150920178)), ('Luis Miguel Antonio Razon', np.float64(0.6860869187982997))]
# Name: Panaguiton, Lei Janrey, Q: 3, Similarity: [('Bianca Clarizze Sollesta', np.float64(0.9927209934087349)), ('Bea Claire Sollesta', np.float64(0.969254235185985)), ('Raymund Sison', np.float64(0.9577087304884172)), ('Axl Roel Andaya', np.float64(0.9521362702371894)), ('Luis Miguel Antonio Razon', np.float64(0.9345792510756072)), ('Leon Antonio C. Besar', np.float64(0.9341955702945891)), ('Kevin Matthew Panuelos', np.float64(0.9197958647051583)), ('BORJA, Jacob M', np.float64(0.8868114299811308))]
# Name: Panopio, Kyrie Caleb, Q: 3, Similarity: [('Axl Roel Andaya', np.float64(0.9647444354267402)), ('BORJA, Jacob M', np.float64(0.9311920883219617)), ('Bianca Clarizze Sollesta', np.float64(0.9284567026649501)), ('Kevin Matthew Panuelos', np.float64(0.9186436527106274)), ('Bea Claire Sollesta', np.float64(0.9180453884403618)), ('Luis Miguel Antonio Razon', np.float64(0.9151101713031267)), ('Leon Antonio C. Besar', np.float64(0.9055573268535464)), ('Raymund Sison', np.float64(0.7816884863113973))]
# Name: Poblete, Erica, Q: 3, Similarity: [('Bianca Clarizze Sollesta', np.float64(0.9889170278924351)), ('Bea Claire Sollesta', np.float64(0.9816280022311441)), ('Axl Roel Andaya', np.float64(0.9761025798267785)), ('Kevin Matthew Panuelos', np.float64(0.9301251766939654)), ('Luis Miguel Antonio Razon', np.float64(0.9203375982692192)), ('BORJA, Jacob M', np.float64(0.9185986731651057)), ('Leon Antonio C. Besar', np.float64(0.917519673572987)), ('Raymund Sison', np.float64(0.9122842782025793))]
# Name: Alcoran, Mark Jhei, Q: 3, Similarity: [('Luis Miguel Antonio Razon', np.float64(0.9673561243809605)), ('Bianca Clarizze Sollesta', np.float64(0.9405314777125676)), ('Axl Roel Andaya', np.float64(0.9403810879192014)), ('Bea Claire Sollesta', np.float64(0.9213162370186684)), ('Leon Antonio C. Besar', np.float64(0.9136267310786936)), ('Kevin Matthew Panuelos', np.float64(0.8795610041580955)), ('BORJA, Jacob M', np.float64(0.8709671002810953)), ('Raymund Sison', np.float64(0.8224364173107174))]
# Name: Moslares, Khim Steffi, Q: 3, Similarity: [('Kevin Matthew Panuelos', np.float64(0.968243950357282)), ('Leon Antonio C. Besar', np.float64(0.9632927204844864)), ('Axl Roel Andaya', np.float64(0.9601635710531228)), ('Bianca Clarizze Sollesta', np.float64(0.9582727556223223)), ('BORJA, Jacob M', np.float64(0.9433870824694158)), ('Luis Miguel Antonio Razon', np.float64(0.9291199856699023)), ('Raymund Sison', np.float64(0.9007323837063538)), ('Bea Claire Sollesta', np.float64(0.8975010757302645))]
#                        Student                      Tutor  Similarity
# 0         Alab, Precious Pearl   Bianca Clarizze Sollesta       0.969
# 1       Alviar, Loissah Mharie              Raymund Sison       0.948
# 2      Capillano, Mhigz Genrei   Bianca Clarizze Sollesta       0.976
# 3           Orain, Mark Angelo   Bianca Clarizze Sollesta       0.973
# 4   Baloaloa, Akhira Charlotte             BORJA, Jacob M       0.984
# 5         Llanto, Didrei Keira              Raymund Sison       0.947
# 6       Panaguiton, Lei Janrey   Bianca Clarizze Sollesta       0.993
# 7         Panopio, Kyrie Caleb            Axl Roel Andaya       0.965
# 8               Poblete, Erica   Bianca Clarizze Sollesta       0.989
# 9           Alcoran, Mark Jhei  Luis Miguel Antonio Razon       0.967
# 10       Moslares, Khim Steffi     Kevin Matthew Panuelos       0.968

# %% [markdown]
# ## Decoupling

# %%
def decouple_and_rerun(student_name, tutor_name, student_tutor_pairs, tutor_pair_count):
      student_tutor_pairs = [pair for pair in student_tutor_pairs if pair[0] != student_name or pair[1] != tutor_name]
      tutor_pair_count[tutor_name] -= 1
